# %%
sample_length = 15000 # This "i" is the number of datapoints we are sampling

# %%
import os
import struct
import numpy as np

"""
Loosely inspired by http://abel.ee.ucla.edu/cvxopt/_downloads/mnist.py
which is GPL licensed.
"""

def read(dataset = "training", path = "."):
    """
    Python function for importing the MNIST data set.  It returns an iterator
    of 2-tuples with the first element being the label and the second element
    being a numpy.uint8 2D array of pixel data for the given image.
    """

    if dataset is "training":
        fname_img = os.path.join(path, 'train-images.idx3-ubyte')
        fname_lbl = os.path.join(path, 'train-labels.idx1-ubyte')
    elif dataset is "testing":
        fname_img = os.path.join(path, 't10k-images-idx3-ubyte')
        fname_lbl = os.path.join(path, 't10k-labels-idx1-ubyte')
    else:
        raise ValueError("dataset must be 'testing' or 'training'")

    # Load everything in some numpy arrays
    with open(fname_lbl, 'rb') as flbl:
        magic, num = struct.unpack(">II", flbl.read(8))
        lbl = np.fromfile(flbl, dtype=np.int8)

    with open(fname_img, 'rb') as fimg:
        magic, num, rows, cols = struct.unpack(">IIII", fimg.read(16))
        img = np.fromfile(fimg, dtype=np.uint8).reshape(len(lbl), rows, cols)

    get_img = lambda idx: (lbl[idx], img[idx])

    # Create an iterator which returns each image in turn
    for i in range(len(lbl)):
        yield get_img(i)

def show(image):
    """
    Render a given numpy.uint8 2D array of pixel data.
    """
    from matplotlib import pyplot
    import matplotlib as mpl
    fig = pyplot.figure()
    ax = fig.add_subplot(1,1,1)
    imgplot = ax.imshow(image, cmap=mpl.cm.Greys)
    imgplot.set_interpolation('nearest')
    ax.xaxis.set_ticks_position('top')
    ax.yaxis.set_ticks_position('left')
    pyplot.show()

# %%
train_data = list(read(dataset='training',path='.'))

# %%
label, pixel = train_data[0]
show(pixel)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  <pre>
#  1. Please download the data set and extract it to current directory
#  2. Run the above cells you get the data in readable formate and pixel formate (60000 * 28 * 28), you can do operations on train_data
#  3. Implement the PCA algorithm on the train data.
#      i.   You can do the pricipal component analysis on smaller data &lt; 60000 (not less than 10k points) data points
#      ii.  Plot the eigen values and eigen vectors
#      iii. Find the varaince explained based on the eigen values we got in step (ii)
#      iii. Select top two eigen values, corresponding eigen vectors and project the data points on those vectors
#      iv.  Plot the resultent lower dimension points with hue="data_labels"
#  4. Use the sklearn libraries pca function
#      i.   Find out the amount of variance explained by each component, select the top components based on this result
#      ii.  Transform the data into lower dimensional data
#      iii. Plot the resultent lower dimension points with hue="data_labels"
#  5. Compare the result of both step 3 and step 4
# </pre>

# %%
import numpy as np
data_all = []
label_all = []
for i in range(0,60000):
    data_all.append(train_data[i][1].flatten())
    label_all.append(train_data[i][0])

# %%
data = data_all[0:sample_length]
data = np.array(data)
label = label_all[0:sample_length]
label = np.array(label)
print (data.shape)
print (np.sum(data))
print (label.shape)
# Out:
# (15000, 784)
# 397383969
# (15000,)

# %%
from sklearn.preprocessing import StandardScaler
stan_data = StandardScaler().fit_transform(data)
print (stan_data.shape, np.sum(stan_data))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# (15000, 784) -3.38218342222e-11

# %% [markdown]
# ## Using sklearn

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2,svd_solver='auto')
new_data = pca.fit_transform(stan_data)
new_data = new_data.T

load_in_df1 = np.array([new_data[0],new_data[1],label])
load_in_df1 = load_in_df1.T
import pandas as pd
df_1 = pd.DataFrame(load_in_df1)
print (df_1.head(3))
df_1.columns = ['PC1','PC2','class']
dist_color = ["#e6194b", "#3cb44b", "#ffe119", "#0082c8", "#46f0f0", "#911eb4", '#aa6e28', '#000000','#f032e6','#aaffc3']
sns.FacetGrid(df_1, hue="class",palette=sns.color_palette(dist_color), size=6) \
   .map(plt.scatter, "PC1",'PC2') \
   .add_legend()
plt.show()
# Out:
#           0         1    2
# 0 -0.960847 -4.456722  5.0
# 1  8.658150 -7.397749  0.0
# 2  2.083071  9.639185  4.0

# %%
print (pca.explained_variance_, pca.explained_variance_ratio_)
# Out:
# [ 41.10062845  30.66109646] [ 0.06008864  0.04482616]

# %% [markdown]
# # Not using sklearn

# %%
c_mat = np.matmul(stan_data.T, stan_data)
c_mat.shape
# Out:
# (784, 784)

# %%
import scipy as sc
val, vec = sc.linalg.eigh(c_mat)
vec.shape
# Out:
# (784, 784)

# %%
vector_1 = []
for i in range(0,784):
    vector_1.append(vec[i][783])
vector_2 = []
for i in range(0,784):
    vector_2.append(vec[i][782])
eig_vec = np.array([vector_1,vector_2])
ekdam_new_coords = np.matmul(eig_vec,stan_data.T)

load_in_df2 = np.array([ekdam_new_coords[0],ekdam_new_coords[1],label])
load_in_df2 = load_in_df2.T
df2 = pd.DataFrame(load_in_df2)
df2.columns = ['PC1','PC2','class']
sns.FacetGrid(df2, hue="class",palette=sns.color_palette(dist_color), size=6) \
   .map(plt.scatter, "PC1",'PC2') \
   .add_legend()
plt.show()
#ekdam_new_coords[1].shape

# %%
plt.plot(val[::-1])
plt.show()

# %%
val[-1] , pca.explained_variance_ # Here we are getting the same eigen-values. Thus our implementation is correct.
# Out:
# (616509.42694773979, array([ 41.10062845,  30.66109646]))
